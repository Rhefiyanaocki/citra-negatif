# %%
# import library

from PIL import Image

# %%
# load citra

CITRA = Image.open('hii.png')

# %%
ukuran_horizontal = CITRA.size[0]
ukuran_vertikal = CITRA.size[1]

# %%
PIXEL = CITRA.load()

# %%
ukuran_horizontal
# Out:
# 1269

# %%
ukuran_vertikal
# Out:
# 637

# %%
for x in range(ukuran_horizontal):
    for y in range(ukuran_vertikal):
        R = 150 - PIXEL[x, y][0]
        G = 150 - PIXEL[x, y][1]
        B = 150 - PIXEL[x, y][2]
        PIXEL[x, y] = (R, G, B)

# %%
CITRA.save('gambar_negatif.png')

# %%
CITRA_NEGATIF = Image.open('gambar_negatif.png')

# %%
CITRA_NEGATIF
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1269x637 at 0x1D64D281940>

# %%
PIXEL[x, y]
# Out:
# (0, 0, 0, 255)
